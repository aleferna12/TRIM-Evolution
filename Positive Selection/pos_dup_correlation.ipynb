# %% [markdown]
# Null hipothesis: positive selection is independent from duplications
#
# Alt hipothesis: positive selection is more common in nodes where a duplication has happened
#
# Reasoning: when a gene duplicates, its more likely that at least one of the children will go through positive selection

# %%
import json
import re
import pandas as pd
from ete3 import Tree
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv("../cluster_seqs.csv", sep=';', index_col=0)
with open("aBSREL Results/trim5.json") as f:
    res = json.load(f)
t = Tree(res["input"]["trees"]["0"] + ";", format=1)
t.remove_child(t & "XM_004389073_2_Trichechus_manatus_latirostris")
# Out:
# Tree node 'XM_004389073_2_Trichechus_manatus_latirostris' (0x2eef64f852)

# %%
for leaf in t.iter_leaves():
    m = re.match(r"[XN]M_\d+_\d+_(.+)", leaf.name)
    leaf.add_features(species=m.group(1))
print(t.get_ascii(show_internal=True))
# Out:
#                             /-XM_012950138_2_Jaculus_jaculus
#                            |
#                            |                                  /-NM_001368753_1_Mus_musculus
#                            |                            /Node13
#                            |                      /Node12     \-NM_001310602_1_Mus_musculus
#                            |                     |     |
#                            |                /Node11     \-NM_001146007_1_Mus_musculus
#                            |               |     |
#                            |          /Node10     \-XM_034506169_1_Arvicanthis_niloticus
#                            |         |     |
#                            |     /Node9     \-NM_001014023_1_Rattus_norvegicus
#                            |    |    |
#                            |    |    |      /-XM_006979025_3_Peromyscus_maniculatus_bairdii
#                        /Node6   |     \Node19
#                       |    |    |          |      /-XM_005370173_3_Microtus_ochrogaster
#                       |    |    |           \Node21
#                       |    |    |                 \-XM_038340689_1_Arvicola_amphibius
#                       |    |    |
#                       |    |    |                                          /-XM_005370165_1_Microtus_ochrogaster
#                       |    |    |                                    /Node30
#                       |    |    |                                   |      \-XM_038350167_1_Arvicola_amphibius
#                       |    |    |                              /Node29
#                       |    |    |                             |     |      /-XM_005370178_2_Microtus_ochrogaster
#                       |    |    |                        /Node28     \Node33
#                       |    |    |                       |     |            \-XM_038338091_1_Arvicola_amphibius
#                       |    |    |                       |     |
#                       |     \Node8                 /Node27     \-XM_038346300_1_Arvicola_amphibius
#                       |         |                 |     |
#                       |         |                 |     |            /-XM_038340326_1_Arvicola_amphibius
#                       |         |                 |     |      /Node38
#                       |         |            /Node26     \Node37     \-XM_026777575_1_Microtus_ochrogaster
#                       |         |           |     |           |
#                       |         |           |     |            \-XM_005370176_1_Microtus_ochrogaster
#                       |         |           |     |
#                       |         |      /Node25    |      /-XM_038323879_1_Arvicola_amphibius
#                       |         |     |     |      \Node42
#                       |         |     |     |            \-XM_013354828_2_Microtus_ochrogaster
#                       |         |     |     |
#                   /Node5        |     |     |      /-XM_015997721_2_Peromyscus_maniculatus_bairdii
#                  |    |         |     |      \Node45
#                  |    |         |     |           |      /-XM_042281162_1_Peromyscus_maniculatus_bairdii
#                  |    |         |     |            \Node47
#                  |    |         |     |                  \-XM_006979028_3_Peromyscus_maniculatus_bairdii
#                  |    |          \Node24
#                  |    |               |                  /-XM_006229915_4_Rattus_norvegicus
#                  |    |               |            /Node52
#                  |    |               |           |     |      /-NM_001378692_1_Mus_musculus
#                  |    |               |      /Node51     \Node54
#                  |    |               |     |     |            \-XM_034523369_1_Arvicanthis_niloticus
#                  |    |               |     |     |
#                  |    |               |     |      \-XM_036153667_1_Mus_musculus
#                  |    |               |     |
#              /Node4   |                \Node50                 /-NM_001357467_1_Mus_musculus
#             |    |    |                     |            /Node60
#             |    |    |                     |           |      \-NM_199146_2_Mus_musculus
#             |    |    |                     |      /Node59
#             |    |    |                     |     |     |            /-XM_034522385_1_Arvicanthis_niloticus
#             |    |    |                     |     |     |      /Node64
#             |    |    |                      \Node58     \Node63     \-XM_034518268_1_Arvicanthis_niloticus
#             |    |    |                           |           |
#             |    |    |                           |            \-XM_034486359_1_Arvicanthis_niloticus
#             |    |    |                           |
#             |    |    |                            \-XM_006229917_4_Rattus_norvegicus
#             |    |    |
#             |    |     \-XM_015477549_1_Marmota_marmota_marmota
#             |    |
#             |    |      /-XM_004589973_3_Ochotona_princeps
#         /Node3    \Node70
#        |    |           \-XM_017341452_1_Oryctolagus_cuniculus
#        |    |
#        |    |            /-XM_009007572_3_Callithrix_jacchus
#        |    |           |
#        |    |           |                        /-NM_001032910_1_Macaca_mulatta
#        |    |           |                  /Node79
#        |    |           |            /Node78     \-NM_001112632_1_Papio_anubis
#        |    |      /Node74          |     |
#        |    |     |     |      /Node77     \-XM_025355630_1_Theropithecus_gelada
#        |    |     |     |     |     |
#        |    |     |     |     |     |      /-XM_023209625_2_Piliocolobus_tephrosceles
#        |    |     |     |     |      \Node83
#        |    |     |      \Node76           \-XM_010364548_2_Rhinopithecus_roxellana
#        |    |     |           |
#        |    |     |           |            /-NM_001280113_1_Nomascus_leucogenys
#        |     \Node73          |      /Node87
#        |          |           |     |      \-NM_001131070_1_Pongo_abelii
#        |          |            \Node86
#        |          |                 |      /-NM_001012650_1_Pan_troglodytes
#        |          |                  \Node90
#        |          |                        \-NM_033034_3_Homo_sapiens
#        |          |
#        |          |      /-XM_045557336_1_Lemur_catta
#        |           \Node93
#        |                 \-NM_001309943_1_Microcebus_murinus
#    /Node2
#   |    |                               /-XM_029956379_1_Suricata_suricatta
#   |    |                        /Node100
#   |    |                       |      |       /-XM_025927911_1_Puma_concolor
#   |    |                       |       \Node102
#   |    |                       |             |       /-XM_043580484_1_Prionailurus_bengalensis
#   |    |                  /Node99             \Node104
#   |    |                 |     |                     \-XM_045038025_1_Felis_catus
#   |    |                 |     |
#   |    |                 |     |       /-XM_032360392_1_Mustela_erminea
#   |    |            /Node98     \Node107
#   |    |           |     |            |       /-XM_021685293_1_Neomonachus_schauinslandi
#   |    |           |     |             \Node109
#   |    |      /Node97    |                    \-XM_026489602_3_Ursus_arctos_horribilis
#   |    |     |     |     |
#   |    |     |     |      \-XM_036927033_1_Manis_pentadactyla
#   |    |     |     |
#   |    |     |      \-XM_012725050_1_Condylura_cristata
#   |    |     |
#   |    |     |                            /-XM_028517106_2_Phyllostomus_discolor
#   |    |     |                     /Node117
#   |    |     |                    |       \-XM_036030159_1_Phyllostomus_discolor
#   |    |     |              /Node116
#   |    |     |             |      |              /-XM_036325207_1_Myotis_myotis
#   |    |     |             |      |       /Node121
#   |    |     |       /Node115      \Node120      \-XM_036325213_1_Myotis_myotis
#   |     \Node96     |      |             |
#   |          |      |      |              \-XM_036325217_1_Myotis_myotis
#   |          |      |      |
#   |          |      |       \-XM_036221648_1_Rousettus_aegyptiacus
#   |          |      |
#   |          |      |                     /-XM_031460181_1_Camelus_dromedarius
#   |          |      |                    |
# --|          |      |                    |              /-XM_015474726_2_Bos_taurus
#   |          |      |                    |       /Node131
#   |          |      |              /Node128     |       \-XM_042233122_1_Ovis_aries
#   |          |      |             |      |      |
#   |          |      |             |      |      |                     /-XM_012095905_4_Ovis_aries
#   |          |      |             |      |      |              /Node136
#   |           \Node114            |       \Node130            |      |       /-XM_006053580_4_Bubalus_bubalis
#   |                 |             |             |       /Node135      \Node138
#   |                 |             |             |      |      |              \-XM_002693205_5_Bos_taurus
#   |                 |             |             |      |      |
#   |                 |             |             |      |       \-XM_043905631_1_Cervus_elaphus
#   |                 |             |              \Node134
#   |                 |             |                    |       /-XM_043905613_1_Cervus_elaphus
#   |                 |             |                    |      |
#   |                 |       /Node127                   |      |              /-NM_001205305_1_Bos_taurus
#   |                 |      |      |                     \Node142            |
#   |                 |      |      |                           |       /Node145             /-XM_024996973_1_Bos_taurus
#   |                 |      |      |                           |      |      |       /Node148
#   |                 |      |      |                           |      |       \Node147      \-XM_006053578_3_Bubalus_bubalis
#   |                 |      |      |                            \Node144            |
#   |                 |      |      |                                  |              \-NM_001034798_1_Bos_taurus
#   |                  \Node126     |                                  |
#   |                        |      |                                  |       /-XM_027979443_2_Ovis_aries
#   |                        |      |                                   \Node152
#   |                        |      |                                          \-NM_001318072_1_Ovis_aries
#   |                        |      |
#   |                        |       \-NM_001044532_1_Sus_scrofa
#   |                        |
#   |                        |       /-XM_001504451_5_Equus_caballus
#   |                         \Node156
#   |                                \-XM_005612109_3_Equus_caballus
#   |
#   |       /-XM_037840276_1_Choloepus_didactylus
#    \Node159
#           \-XM_037840283_1_Choloepus_didactylus

# %%
def positive_child(node):
    for child in node.children:
        child_stats = res["branch attributes"]["0"][child.name]
        if child_stats["Corrected P-value"] <= 0.05:
            return True
    return False

# %%
# Indicate that positive selection happened at this node (Cholopus seqs) but not in correlation with a duplication
posdf = pd.DataFrame(index=["Root", "Node0"], data={"pos_sel": [False, True], "dup": [False, False]})
cached_sps = t.get_cached_content(store_attr="species")
for node in t.iter_descendants():
    if not node.is_leaf():
        for sp in cached_sps[node]:
            if sp in cached_sps[node.children[0]] and sp in cached_sps[node.children[1]]:
                posdf.loc[node.name, "dup"] = True
                break
            else:
                posdf.loc[node.name, "dup"] = False
        if positive_child(node):
            posdf.loc[node.name, "pos_sel"] = True
        else:
            posdf.loc[node.name, "pos_sel"] = False
posdf
# Out:
#         pos_sel    dup
# Root      False  False
# Node0      True  False
# Node2      True  False
# Node159   False   True
# Node3      True  False
# ...         ...    ...
# Node64    False   True
# Node147   False   True
# Node30    False  False
# Node33    False  False
# Node148   False  False
#
# [81 rows x 2 columns]

# %%
cross = pd.crosstab(index=posdf["pos_sel"], columns=posdf["dup"])
cross
# Out:
# dup      False  True
# pos_sel
# False       40    15
# True        16    10

# %%
chi_res = chi2_contingency(cross)
chi_res[1]  # P value
# Out:
# 0.44718681462651844

# %% [markdown]
# Not significative :(
